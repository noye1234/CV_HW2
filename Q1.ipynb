# %% [markdown]
# <a href="https://colab.research.google.com/github/noye1234/CV_HW2/blob/main/Q1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Student Information
# - Full name: Noy Elisha
# - ID number: 213419500

# %% [markdown]
# #libraries

# %%
import cv2

# %% [markdown]
# #Question 1 — Convolution

# %%
img=cv2.imread('')
